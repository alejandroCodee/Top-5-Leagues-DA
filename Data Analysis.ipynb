# %%
import pandas as pd

df = pd.read_csv("top_5_leagues_player.csv")

# %%
df
# Out:
#       Unnamed: 0                name                     full_name  age  \
# 0              0             Ederson                           NaN   29
# 1              1       Stefan Ortega          Stefan Ortega Moreno   30
# 2              2        Scott Carson             Scott Paul Carson   37
# 3              3          Rúben Dias  Rúben Santos Gato Alves Dias   26
# 4              4          Nathan Aké           Nathan Benjamin Aké   28
# ...          ...                 ...                           ...  ...
# 2607        2607       Moussa Djitté         Moussa Kalilou Djitté   23
# 2608        2608  Mounaïm El Idrissy                 منعم الإدريسي   24
# 2609        2609      Moussa Soumano                           NaN   17
# 2610        2610      Romain Hamouma                           NaN   36
# 2611        2611      Yoann Touzghar                           NaN   36
#
#       height                 nationality place_of_birth  price  max_price  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
#Primero, vamos a eliminar los duplicados con un simple comando.

df.shape[0]
# Out:
# 2612

# %%
df = df.drop_duplicates()

# %%
df.shape[0]
# Out:
# 2612

# %%
#No habían duplicados.

# %%
df["age"].dtype
# Out:
# dtype('int64')

# %%
df.describe()
# Out:
#         Unnamed: 0          age       height        price    max_price  \
# count  2612.000000  2612.000000  2601.000000  2602.000000  2606.000000
# mean   1305.500000    26.305513     1.830892    10.650711    17.304729
# std     754.163775     4.645297     0.067255    15.773271    21.948577
# min       0.000000    17.000000     1.630000     0.025000     0.025000
# 25%     652.750000    23.000000     1.780000     1.800000     3.500000
# 50%    1305.500000    26.000000     1.830000     4.500000    10.000000
# 75%    1958.250000    30.000000     1.880000    13.000000    22.000000
# max    2611.000000    42.000000     2.060000   180.000000   200.000000
#
#           shirt_nr
# count  2612.000000
# mean     20.495789
# std      17.914206
# min       1.000000
# 25%       8.000000
# 50%      17.000000
# 75%      27.000000
# max      99.000000

# %%
df["shirt_nr"].dtype
# Out:
# dtype('int64')

# %%
df.head(10)
# Out:
#    Unnamed: 0             name                                   full_name  \
# 0           0          Ederson                                         NaN
# 1           1    Stefan Ortega                        Stefan Ortega Moreno
# 2           2     Scott Carson                           Scott Paul Carson
# 3           3       Rúben Dias                Rúben Santos Gato Alves Dias
# 4           4       Nathan Aké                         Nathan Benjamin Aké
# 5           5      John Stones                                         NaN
# 6           6  Aymeric Laporte  Aymeric Jean Louis Gerard Alphonse Laporte
# 7           7    Manuel Akanji                       Manuel Obafemi Akanji
# 8           8     Sergio Gómez                         Sergio Gómez Martín
# 9           9   Benjamin Mendy                                         NaN
#
#    age  height                 nationality place_of_birth  price  max_price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2612 entries, 0 to 2611
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2612 non-null   int64
#  1   name              2612 non-null   object
#  2   full_name         1480 non-null   object
#  3   age               2612 non-null   int64
#  4   height            2601 non-null   float64
#  5   nationality       2612 non-null   object
#  6   place_of_birth    2595 non-null   object
#  7   price             2602 non-null   float64
#  8   max_price         2606 non-null   float64
#  9   position          2612 non-null   object
#  10  shirt_nr          2612 non-null   int64
#  11  foot              2576 non-null   object
#  12  club              2612 non-null   object
#  13  contract_expires  2544 non-null   object
#  14  joined_club       2612 non-null   object
#  15  player_agent      2353 non-null   object
# ...

# %%
df.loc[0:19, "full_name"]
# Out:
# 0                                            NaN
# 1                           Stefan Ortega Moreno
# 2                              Scott Paul Carson
# 3                   Rúben Santos Gato Alves Dias
# 4                            Nathan Benjamin Aké
# 5                                            NaN
# 6     Aymeric Jean Louis Gerard Alphonse Laporte
# 7                          Manuel Obafemi Akanji
# 8                            Sergio Gómez Martín
# 9                                            NaN
# 10                            Kyle Andrew Walker
# 11                         Rico Henry Mark Lewis
# 12                                           NaN
# 13                          Kalvin Mark Phillips
# 14                                           NaN
# 15                                İlkay Gündoğan
# 16                                           NaN
# 17       Bernardo Mota Veiga de Carvalho e Silva
# 18                          Cole Jermaine Palmer
# ...

# %%
df.loc[:,"club"]
# Out:
# 0         Man City
# 1         Man City
# 2         Man City
# 3         Man City
# 4         Man City
#            ...
# 2607    AC Ajaccio
# 2608    AC Ajaccio
# 2609    AC Ajaccio
# 2610    AC Ajaccio
# 2611    AC Ajaccio
# Name: club, Length: 2612, dtype: object

# %%
df.loc[0:50, "club"]
# Out:
# 0        Man City
# 1        Man City
# 2        Man City
# 3        Man City
# 4        Man City
# 5        Man City
# 6        Man City
# 7        Man City
# 8        Man City
# 9        Man City
# 10       Man City
# 11       Man City
# 12       Man City
# 13       Man City
# 14       Man City
# 15       Man City
# 16       Man City
# 17       Man City
# 18       Man City
# 19       Man City
# 20       Man City
# 21       Man City
# 22       Man City
# 23       Man City
# 24        Chelsea
# 25        Chelsea
# 26        Chelsea
# 27        Chelsea
# 28        Chelsea
# 29        Chelsea
# 30        Chelsea
# 31        Chelsea
# 32        Chelsea
# 33        Chelsea
# 34        Chelsea
# 35    Chelsea U21
# 36        Chelsea
# 37        Chelsea
# 38        Chelsea
# 39        Chelsea
# 40        Chelsea
# 41        Chelsea
# 42        Chelsea
# 43        Chelsea
# 44        Chelsea
# 45        Chelsea
# 46        Chelsea
# 47        Chelsea
# 48        Chelsea
# 49        Chelsea
# ...
